# %%
print("cek")
# Out:
# cek

# %%
import random
import time
import math

def calculate_pi_serial(num_samples):
    inside_circle = 0
    
    for _ in range(num_samples):
        x = random.uniform(-1, 1)
        y = random.uniform(-1, 1)
        
        # Cek apakah titik berada dalam lingkaran
        if x**2 + y**2 <= 1:
            inside_circle += 1
    
    pi_estimate = 4 * inside_circle / num_samples
    return pi_estimate

# Testing
if __name__ == "__main__":
    num_samples = 10_000_000
    
    start_time = time.time()
    pi_est = calculate_pi_serial(num_samples)
    end_time = time.time()
    
    print(f"Estimasi π: {pi_est}")
    print(f"Nilai asli π: {math.pi}")
    print(f"Error: {abs(pi_est - math.pi)}")
    print(f"Waktu eksekusi: {end_time - start_time:.4f} detik")
# Out:
# Estimasi π: 3.1411396
# Nilai asli π: 3.141592653589793
# Error: 0.00045305358979330634
# Waktu eksekusi: 4.8762 detik

# %%
import multiprocessing
import random
import time
import math

def monte_carlo_chunk(chunk_size):
    """Menghitung titik dalam lingkaran untuk sejumlah sampel"""
    inside = 0
    for _ in range(chunk_size):
        x = random.uniform(-1, 1)
        y = random.uniform(-1, 1)
        if x**2 + y**2 <= 1:
            inside += 1
    return inside

def calculate_pi_parallel(num_samples, num_processes):
    """Menghitung π menggunakan multiprocessing"""
    chunk_size = num_samples // num_processes
    
    # Buat pool worker
    with multiprocessing.Pool(processes=num_processes) as pool:
        results = pool.map(monte_carlo_chunk, [chunk_size] * num_processes)
    
    total_inside = sum(results)
    pi_estimate = 4 * total_inside / (chunk_size * num_processes)
    return pi_estimate

# Testing dengan berbagai jumlah proses
if __name__ == "__main__":
    num_samples = 10_000_000
    
    for num_procs in [1, 2, 4, 8, 16, 32]:
        start_time = time.time()
        pi_est = calculate_pi_parallel(num_samples, num_procs)
        end_time = time.time()
        
        print(f"\nProses: {num_procs}")
        print(f"  Estimasi π: {pi_est}")
        print(f"  Waktu: {end_time - start_time:.4f} detik")
# Out:
# Proses: 1
#   Estimasi π: 3.1424588
#   Waktu: 5.0144 detik
#
# Proses: 2
#   Estimasi π: 3.1409816
#   Waktu: 2.8249 detik
#
# Proses: 4
#   Estimasi π: 3.1420736
#   Waktu: 1.9872 detik
#
# Proses: 8
#   Estimasi π: 3.1414468
#   Waktu: 1.5366 detik
#
# Proses: 16
#   Estimasi π: 3.1405032
#   Waktu: 1.5965 detik
#
# Proses: 32
#   Estimasi π: 3.1416456
#   Waktu: 1.5136 detik

# %%
import matplotlib.pyplot as plt

process_counts = [1, 2, 4, 8, 16, 32]
execution_times = [5.0144, 2.8249, 1.9872, 1.5366, 1.5965, 1.5136]
speedups = [0.966, 1.715, 2.438, 3.154, 3.035, 3.201]
efficiencies = [0.966, 0.858, 0.6095, 0.394, 0.189, 0.100]

plt.figure(figsize=(10, 6))
plt.plot(process_counts, execution_times, marker='o')
plt.xlabel("Jumlah Proses")
plt.ylabel("Waktu Eksekusi (detik)")
plt.title("Waktu Eksekusi vs Jumlah Proses")
plt.grid(True)
plt.savefig("execution_time.png")
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(process_counts, speedups, marker='o', label="Speedup Aktual")
plt.plot(process_counts, process_counts, linestyle='--', label="Speedup Ideal")
plt.xlabel("Jumlah Proses")
plt.ylabel("Speedup")
plt.title("Speedup vs Jumlah Proses")
plt.legend()
plt.grid(True)
plt.savefig("speedup_analysis.png")
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(process_counts, efficiencies, marker='o')
plt.xlabel("Jumlah Proses")
plt.ylabel("Efficiency")
plt.title("Efficiency vs Jumlah Proses")
plt.grid(True)
plt.savefig("efficiency_analysis.png")
plt.show()
